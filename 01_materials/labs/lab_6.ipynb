# %% [markdown]
# Module: Deep learning<br>
# Lab: 6<br>
# Name: Chun-Yuan Chen<br>

# %% [markdown]
# ## Text classification using Neural Networks
#
# The goal of this notebook is to learn to use Neural Networks for text classification.
#
# In this notebook, we will:
# - Train a shallow model with learning embeddings
# - Download pre-trained embeddings from Glove
# - Use these pre-trained embeddings

# %% [markdown]
# ## The BBC topic classification dataset
#
# The BBC provides some benchmark topic classification datasets in English at: http://mlg.ucd.ie/datasets/bbc.html.
#
# The raw text (encoded with the latin-1 character encoding) of the news can be downloaded as a ZIP archive:

# %%
import os # interacts with the operating system
import os.path as op # helps with file path operations
import zipfile 
from urllib.request import urlretrieve # downloads files from a URL

BBC_DATASET_URL = "http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip"

zip_filename = BBC_DATASET_URL.rsplit('/', 1)[1] # stores the extracted filename

BBC_DATASET_FOLDER = 'bbc'

if not op.exists(zip_filename):
    print("Downloading %s to %s..." % (BBC_DATASET_URL, zip_filename))
    urlretrieve(BBC_DATASET_URL, zip_filename)

if not op.exists(BBC_DATASET_FOLDER):
    with zipfile.ZipFile(zip_filename, 'r') as f:
        print("Extracting contents of %s..." % zip_filename)
        f.extractall('.')
# Out:
# Downloading http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip to bbc-fulltext.zip...
# Extracting contents of bbc-fulltext.zip...

# %% [markdown]
# Each of the five folders contains text files from one of the five topics:

# %%
target_names = sorted(folder for folder in os.listdir(BBC_DATASET_FOLDER)
                      if op.isdir(op.join(BBC_DATASET_FOLDER, folder)))
target_names
# Out:
# ['business', 'entertainment', 'politics', 'sport', 'tech']

# %%
# Example of a file in the "business" category
with open(op.join(BBC_DATASET_FOLDER, 'business', '001.txt'), 'rb') as f:
    print(f.read().decode('latin-1')[:500] + '...') # extracts the first 500 characters of the decoded text & an ellipsis to indicate that the text is truncated.
# Out:
# Ad sales boost Time Warner profit
#
# Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (Â£600m) for the three months to December, from $639m year-earlier.
#
# The firm, which is now one of the biggest investors in Google, benefited from sales of high-speed internet connections and higher advert sales. TimeWarner said fourth quarter sales rose 2% to $11.1bn from $10.9bn. Its profits were buoyed by one-off gains which offset a profit dip at Warner Bros, and less users for AOL.
#
# Time ...

# %% [markdown]
# Let's randomly partition the text files in a training and test set while recording the target category of each file as an integer:

# %%
import numpy as np
from sklearn.model_selection import train_test_split

target = []
filenames = []

for target_id, target_name in enumerate(target_names):
    class_path = op.join(BBC_DATASET_FOLDER, target_name) # e.g. 'bbc/business'

    for filename in sorted(os.listdir(class_path)):
        filenames.append(op.join(class_path, filename))
        target.append(target_id)

target = np.asarray(target, dtype=np.int32)

target_train, target_test, filenames_train, filenames_test = train_test_split(
    target, filenames, test_size=200, random_state=0)

# %% [markdown]
# What we now have is pairs of target labels (which category the document belongs to) and filenames (where the document is stored on disk):

# %%
target_train[:5], filenames_train[:5]
# Out:
# (array([0, 1, 3, 4, 3], dtype=int32),
#  ['bbc\\business\\475.txt',
#   'bbc\\entertainment\\152.txt',
#   'bbc\\sport\\127.txt',
#   'bbc\\tech\\095.txt',
#   'bbc\\sport\\464.txt'])

# %%
size_in_bytes = sum([len(open(fn, 'rb').read()) for fn in filenames_train])
print("Training set size: %0.3f MB" % (size_in_bytes / 1e6))
# Out:
# Training set size: 4.582 MB

# %% [markdown]
# This dataset is small so we can load everything into memory right now (which simplifies our code later). If we had substantially more data, we would need to use a `tf.data.Dataset` to stream it from disk in batches during training.

# %%
texts_train = [open(fn, 'rb').read().decode('latin-1') for fn in filenames_train]
texts_test = [open(fn, 'rb').read().decode('latin-1') for fn in filenames_test]

# %% [markdown]
# ## A first baseline model
#
# For simple topic classification problems, one should always try a simple method first. Let's try using a `CountVectorizer` followed by `LogisticRegression` as a baseline. What this will do is:
#
# - Convert the text documents to a matrix of token counts (each row is a document, each column is a word, each cell is the count of the word in the document)
# - Train a logistic regression model on this matrix
#
# It's a very efficient method and should give us a strong baseline to compare our deep learning method against.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Understanding what the CountVectorizer does
vectorizer = CountVectorizer(max_features=2000) # only keep the 2000 most frequent words
X_train = vectorizer.fit_transform(texts_train) # learns the vocabulary from texts_train and transforms each document into a sparse matrix of word count


# Compare the content of the first document with the vocabulary
print("Start of the first document:")
print(texts_train[0][0:100] + '...') # displays the first 100 characters of the first document
print('----------')
print("Sampling of vocabulary counts in the document:")
for word, count in zip(vectorizer.get_feature_names_out()[200:210], X_train.toarray()[0][200:210]):
    print(word, count)
    # selects a slice of 10 words from position 200 to 209
    # X_train.toarray()[0]: gets the word count vector for the first document
# Out:
# Start of the first document:
# Watchdog probes Vivendi bond sale
#
# French stock market regulator AMF has filed complaints against me...
# ----------
# Sampling of vocabulary counts in the document:
# bank 2
# bankruptcy 0
# banks 0
# barcelona 0
# based 0
# basic 0
# basis 1
# bath 0
# battle 0
# bbc 0

# %% [markdown]
# > CYC notes:<br>
# > From the above output, get to know how often certain words show up in this document (e.g., bank twice, bbc not at all).

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline


text_classifier = make_pipeline(
    CountVectorizer(max_features=2000),
    # Converts text into numerical features by counting word frequencies, keeping only the top 2000 most frequent words.

    LogisticRegression(max_iter=1000),
    # model for used for classification, set #iterations to converge during training.
)

# %%
# %time _ = text_classifier.fit(texts_train, target_train)
    # text_classifier.fit: trains the pipeline CountVectorizer + LogisticRegression
    # uses the training texts (texts_train) and their corresponding labels (target_train)
    # texts_train from the ealier cell [open(fn, 'rb').read().decode('latin-1') for fn in filenames_train]
    # %time: measures and prints how long the training takes to run
# Out:
# CPU times: total: 1.12 s
# Wall time: 1.41 s

# %% [markdown]
# Let's check the accuracy of this baseline model on the test set:

# %%
text_classifier.score(texts_test, target_test) # calculates the accuracy of the trained text classification model on the test set.
# Out:
# 0.96

# %% [markdown]
# Approximately 95 percent testing accuracy on a very simple baseline. It's quite unlikely that we can significantly beat that baseline with a more complex deep learning based model. This is simply not a complex task - we wouldn't expect to see this level of performance from a simple model on a real-world text classification problem. Let's move on, and see how well we can do with a simple neural network.

# %% [markdown]
# ### Preprocessing text for the (supervised) CBOW model
#
# We will implement a simple classification model in Keras. Raw text requires (sometimes a lot of) preprocessing.
#
# The following cells uses Keras to preprocess text:
# - using a tokenizer. This converts the texts into sequences of indices representing the `20000` most frequent words
# - sequences have different lengths, so we pad them (add 0s at the end until the sequence is of length `1000`). For example, if we were padding to three words, and we had a sequence of just "dog", we would pad it to "[\<dog token\>,0,0]".
# - we convert the output classes as 1-hot encodings

# %% [markdown]
# > CYC notes for CBOW (Continuous Bag of Words):<br>
# > I guess it would like, for example...<br>
# > (1) text = "The dog barked loudly"<br>
# > (2) tokenization: {'the': 1, 'dog': 2, 'barked': 3, 'loudly': 4}<br>
# > (3) sequence [1, 2, 3, 4] >>> padding [1, 2, 3, 4, 0, 0]<br>
# > (4) one-hot encoding for labels [1, 0, 0] assuming [dog, cat, bird]<br>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer # helps turn words into numbers

MAX_NB_WORDS = 20000 # set 20,000 most frequent words will be kept 

# vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, char_level=False)
    # creates a tokenizer object
    # char_level=False: tokenizes by words, not characters

tokenizer.fit_on_texts(texts_train)
    # learns the vocabulary from the training texts

sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
    # converts each text into a list of numbers (word indices)

word_index = tokenizer.word_index
    # a ddictionary mapping each word to its index

print('Found %s unique tokens.' % len(word_index)) # prints how many unique words were found
print(f'Example of word_index: {list(word_index.items())[:5]}') # shows the first 5 word-to-index pairs
# Out:
# Found 30995 unique tokens.
# Example of word_index: [('the', 1), ('to', 2), ('of', 3), ('and', 4), ('a', 5)]

# %% [markdown]
# Tokenized sequences are converted to list of token ids (with an integer code). We can convert them back to text to see what they now look like:

# %%
index_to_word = dict((i, w) for w, i in tokenizer.word_index.items())

# %%
print(f'Original text:          {texts_train[0].split(" ")[0:4]}') # displays the first 4 words of the original text
print(f'Tokenized text:         {sequences[0][0:4]}') # shows the first 4 word indices from the tokenized version of the text
print(f'Converted back to text: {[index_to_word.get(i, "UNK") for i in sequences[0][0:4]]}')
    # converts those indices back into words
    # "UNK" stands for "unknown" used if a word index isn't found
# Out:
# Original text:          ['Watchdog', 'probes', 'Vivendi', 'bond']
# Tokenized text:         [1857, 9454, 5251, 1973]
# Converted back to text: ['watchdog', 'probes', 'vivendi', 'bond']

# %% [markdown]
# Let's have a closer look at the tokenized sequences:

# %%
seq_lens = [len(s) for s in sequences] # creates a list of sequence lengths
print("average length: %0.1f" % np.mean(seq_lens)) # calculates the average number of tokens per text
print("max length: %d" % max(seq_lens)) # finds the longest text in terms of token count
# Out:
# average length: 382.6
# max length: 4355

# %%
import matplotlib.pyplot as plt

plt.hist(seq_lens, bins=50);

# %% [markdown]
# We can see that while we do have sequences up to 4355 words long, the vast majority of sequences are less than 1000 words long. We can use this information to truncate or pad all the sequences to 1000 symbols to build the training set. This will simplify our model and speed up training.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences # adds padding to make all sequences the same length

MAX_SEQUENCE_LENGTH = 1000 # sets the target length for each sequence

# Make all sequences exactly 1000 words long
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH) # sequences from tokenizer.texts_to_sequences(texts_train)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH) # sequences_test from tokenizer.texts_to_sequences(texts_test)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2025, 1000)
# Shape of data test tensor: (200, 1000)

# %% [markdown]
# > CYC notes:<br>
# > From the above output, (2025, 1000) means that 2025 training samples, each one is a text. Each sample has been paded/truncated to exactly 1000 words.

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(target_train)
print('Shape of label tensor:', y_train.shape)
# Out:
# Shape of label tensor: (2025, 5)

# %% [markdown]
# > CYC notes:<br>
# > 2025 training samples, each label is now a vector of length 5 (for 5 possible classes).<br>
# > For example, target_train = [0, 2, 1] >>> y_train = [[1, 0, 0], [0, 0, 1], [0, 1, 0]]<br>

# %% [markdown]
# ### A simple supervised CBOW model in Keras
#
# The following computes a very simple model, as described in [fastText](https://github.com/facebookresearch/fastText):
#
# <img src="https://raw.githubusercontent.com/UofT-DSI/deep_learning/58b409e83f4294b293d6f763abf889d0a0fa1ddf/03_instructional_team/markdown_slides/images/svg_files/06_fasttext.svg" style="width: 600px;" />
#
# - Build an embedding layer mapping each word to a vector representation
# - Compute the vector representation of all words in each sequence and average them
# - Add a dense layer to output 5 classes

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling1D, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

EMBEDDING_DIM = 50 # each word will be represented by a 50-dimensional vector
N_CLASSES = len(target_names) # number of output categories

model = Sequential([ 
    # stacks layers one after another

    Embedding(MAX_NB_WORDS, EMBEDDING_DIM, trainable=True), # Just like we've seen in previous labs
    # MAX_NB_WORDS: maximum number of unique words the model will handle
    # EMBEDDING_DIM: each word becomes a 50-number vector
    # trainable=True: These vectors can be updated during training

    GlobalAveragePooling1D(), # This layer averages the embeddings of all words in the sequence
    # helps reduce the data size and focus on overall meaning

    Dense(N_CLASSES, activation='softmax') # This layer outputs a probability distribution over the 5 classes
])

model.compile(
    loss='categorical_crossentropy', 
    optimizer=Adam(learning_rate=0.01),
    metrics=['accuracy']
)

# %%
model.fit(x_train, y_train, validation_split=0.1, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2842 - loss: 1.6159 - val_accuracy: 0.7241 - val_loss: 1.2020
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5779 - loss: 1.1579 - val_accuracy: 0.7635 - val_loss: 0.7888
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7896 - loss: 0.7076 - val_accuracy: 0.7537 - val_loss: 0.6112
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8532 - loss: 0.4450 - val_accuracy: 0.8424 - val_loss: 0.4181
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8688 - loss: 0.3527 - val_accuracy: 0.9606 - val_loss: 0.2093
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9333 - loss: 0.2150 - val_accuracy: 0.9507 - val_loss: 0.1700
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.1114 - val_accuracy: 0.9360 - val_loss: 0.1969
# Epoch 8/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9734 - loss: 0.1161 - val_accuracy: 0.9360 - val_loss: 0.1537
# Epoch 9/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9739 - loss: 0.1055 - val_accuracy: 0.6108 - val_loss: 1.3373
# Epoch 10/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8362 - loss: 0.4734 - val_accuracy: 0.9704 - val_loss: 0.1254

# %% [markdown]
# **Exercise**
#
# - Evaluate the model on the test set
# - Identify an example of a mis-classified document and display the text of the document

# %%
# Evaluate the model
y_test = to_categorical(target_test)

loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9346 - loss: 0.2047
# Test Loss: 0.2137
# Test Accuracy: 0.9350

# %%
y_pred_probs = model.predict(x_test)  # gets predicted probabilities

y_pred_labels = np.argmax(y_pred_probs, axis=1) # gets predicted class labels

y_true_labels = np.argmax(y_test, axis=1)  # gets true class labels

misclassified_cases = np.where(y_pred_labels != y_true_labels)[0]

if len(misclassified_cases) > 0:
    index = misclassified_cases[6]
    print(f"\nMisclassified text index: {index}")
    print(f"True label: {target_names[y_true_labels[index]]}")
    print(f"Predicted label: {target_names[y_pred_labels[index]]}")
    print(f"Original text:\n{texts_test[index]}")
else:
    print("No misclassified cases.")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Misclassified text index: 112
# True label: business
# Predicted label: tech
# Original text:
# Ask Jeeves tips online ad revival
#
# Ask Jeeves has become the third leading online search firm this week to thank a revival in internet advertising for improving fortunes.
#
# The firm's revenue nearly tripled in the fourth quarter of 2004, exceeding $86m (Â£46m). Ask Jeeves, once among the best-known names on the web, is now a relatively modest player. Its $17m profit for the quarter was dwarfed by the $204m announced by rival Google earlier in the week. During the same quarter, Yahoo earned $187m, again tipping a resurgence in online advertising.
#
# The trend has taken hold relatively quickly. Late last year, marketing company Doubleclick, one of the leading providers of online advertising, warned that some or all of its business would have to be put up for sale. But on Thursday, it announced that a sharp turnaround had brought about an unexpected increase in profits. Neither Ask Jeeves nor Doubleclick thrilled investors with their profit news, however. In both cases, their shares fell by some 4%. Analysts attributed the falls to excessive expectations in some quarters, fuelled by the dramatic outperformance of Google on Tuesday.

# %% [markdown]
# > CYC notes:<br>
# > The index 112 case is interesting. I thought it was misclassified, by this simple model, as tech due to several possible reasons, one of them I can guess is that the text includes many tech-heavy words like Google, Yahoo, etc, as well as other words associated with tech like web and online.

# %% [markdown]
# ### Building more complex models
#
# **Exercise**
# - Copy the previous model, and add more complexity to it. You can try adding more layers, or using a different type of layer (e.g. LSTM, Conv1D, etc.)
# - Some examples of what you could do:
#     - Add a LSTM layer before the dense layer ([LSTM documentation](https://keras.io/layers/recurrent/#lstm))
#     - Add a Conv1D layer after the embedding layer ([Conv1D documentation](https://keras.io/layers/convolutional/#conv1d))
#     - Add more dense layers

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Embedding, LSTM
from tensorflow.keras.models import Sequential

EMBEDDING_DIM = 50 # each word will be represented by a 50-dimensional vector
N_CLASSES = len(target_names) # number of output categories

model_complex = Sequential([ 
    # stacks layers one after another

    Embedding(MAX_NB_WORDS, EMBEDDING_DIM, trainable=True), # Just like we've seen in previous labs
    # MAX_NB_WORDS: maximum number of unique words the model will handle
    # EMBEDDING_DIM: each word becomes a 50-number vector
    # trainable=True: These vectors can be updated during training

    Conv1D(filters=64, kernel_size=5, activation='relu'),

    LSTM(64, return_sequences=True),

    GlobalAveragePooling1D(), # This layer averages the embeddings of all words in the sequence
    # helps reduce the data size and focus on overall meaning

    Dense(64, activation='relu'),

    Dense(N_CLASSES, activation='softmax') # This layer outputs a probability distribution over the 5 classes
])

model_complex.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %% [markdown]
# > CYC notes:<br>
# > Compared to the simple model, three layers were added,<br>
# > Conv1D(filters=64, kernel_size=5, activation='relu') >>> expect improving detect local patterns (e.g., phrases)<br>
# > LSTM(64) >>> helps capture long-term dependencies & word order >>> expect improving context<br>
# > Dense(64, activation='relu') >>> expect improving learn more complex feature interactions<br>

# %%
model_complex.fit(x_train, y_train, validation_split=0.1, epochs=15, batch_size=32) # epochs=10 >>> epochs=15, expect improving generalization

output_test = model_complex(x_test)
test_casses = np.argmax(output_test, axis=-1)

print("Test accuracy:", np.mean(test_casses == target_test))
# Out:
# Epoch 1/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.3083 - loss: 1.4335 - val_accuracy: 0.8374 - val_loss: 0.4370
# Epoch 2/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 13s 233ms/step - accuracy: 0.9360 - loss: 0.2015 - val_accuracy: 0.9557 - val_loss: 0.1743
# Epoch 3/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 240ms/step - accuracy: 0.9912 - loss: 0.0268 - val_accuracy: 0.9163 - val_loss: 0.2517
# Epoch 4/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 247ms/step - accuracy: 0.9873 - loss: 0.0430 - val_accuracy: 0.9754 - val_loss: 0.0779
# Epoch 5/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 250ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9704 - val_loss: 0.0667
# Epoch 6/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 1.0000 - loss: 7.1434e-04 - val_accuracy: 0.9704 - val_loss: 0.0665
# Epoch 7/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 1.0000 - loss: 3.9144e-04 - val_accuracy: 0.9754 - val_loss: 0.0711
# Epoch 8/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 1.0000 - loss: 3.2953e-04 - val_accuracy: 0.9704 - val_loss: 0.0737
# Epoch 9/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 15s 265ms/step - accuracy: 1.0000 - loss: 2.6651e-04 - val_accuracy: 0.9704 - val_loss: 0.0773
# Epoch 10/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 1.0000 - loss: 2.1031e-04 - val_accuracy: 0.9704 - val_loss: 0.0822
# Epoch 11/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 1.0000 - loss: 1.7199e-04 - val_accuracy: 0.9704 - val_loss: 0.0859
# Epoch 12/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 1.0000 - loss: 1.4053e-04 - val_accuracy: 0.9704 - val_loss: 0.0896
# Epoch 13/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 13s 225ms/step - accuracy: 1.0000 - loss: 1.1592e-04 - val_accuracy: 0.9655 - val_loss: 0.0929
# Epoch 14/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 15s 266ms/step - accuracy: 1.0000 - loss: 1.1714e-04 - val_accuracy: 0.9655 - val_loss: 0.0954
# Epoch 15/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 1.0000 - loss: 9.5787e-05 - val_accuracy: 0.9655 - val_loss: 0.0991
# Test accuracy: 0.96

# %% [markdown]
# > CYC notes:<br>
# > Great! For test accuracy, 0.96 (complex model) > 0.9350 (simple model).

# %% [markdown]
# ### Loading pre-trained embeddings
#
# The file `glove100K.100d.txt` is an extract of [Glove](http://nlp.stanford.edu/projects/glove/) Vectors, that were trained on English Wikipedia and the Gigaword 5 corpus. They differ from word2vec in the way the vectors are trained, but the idea is the same: each word is represented as a vector of `100` numbers.
#
# We extracted the `100 000` most frequent words for you, and the code below downloads them.

# %%
# Get pretrained Glove Word2Vec
URL_REPRESENTATIONS = "https://github.com/m2dsupsdlclass/lectures-labs/releases/download/0.3/glove100k.100d.zip"
ZIP_REPRESENTATIONS = "glove100k.100d.zip"
FILE_REPRESENTATIONS = "glove100K.100d.txt"

if not op.exists(ZIP_REPRESENTATIONS):
    print('Downloading from %s to %s...' % (URL_REPRESENTATIONS, ZIP_REPRESENTATIONS))
    urlretrieve(URL_REPRESENTATIONS, './' + ZIP_REPRESENTATIONS)

if not op.exists(FILE_REPRESENTATIONS):
    print("extracting %s..." % ZIP_REPRESENTATIONS)
    myzip = zipfile.ZipFile(ZIP_REPRESENTATIONS)
    myzip.extractall()
# Out:
# Downloading from https://github.com/m2dsupsdlclass/lectures-labs/releases/download/0.3/glove100k.100d.zip to glove100k.100d.zip...
# extracting glove100k.100d.zip...

# %%
embeddings_index = {}
embeddings_vectors = []
with open('glove100K.100d.txt', 'rb') as f:
    word_idx = 0
    for line in f:
        values = line.decode('utf-8').split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = word_idx
        embeddings_vectors.append(vector)
        word_idx = word_idx + 1

inv_index = {v: k for k, v in embeddings_index.items()}
print("found %d different words in the file" % word_idx)
# Out:
# found 100000 different words in the file

# %%
# Stack all embeddings in a large numpy array
glove_embeddings = np.vstack(embeddings_vectors)
glove_norms = np.linalg.norm(glove_embeddings, axis=-1, keepdims=True)
glove_embeddings_normed = glove_embeddings / glove_norms
print(glove_embeddings.shape)
# Out:
# (100000, 100)

# %%
def get_emb(word):
    idx = embeddings_index.get(word)
    if idx is None:
        return None
    else:
        return glove_embeddings[idx]

    
def get_normed_emb(word):
    idx = embeddings_index.get(word)
    if idx is None:
        return None
    else:
        return glove_embeddings_normed[idx]

# %%
get_emb("computer")
# Out:
# array([-1.6298e-01,  3.0141e-01,  5.7978e-01,  6.6548e-02,  4.5835e-01,
#        -1.5329e-01,  4.3258e-01, -8.9215e-01,  5.7747e-01,  3.6375e-01,
#         5.6524e-01, -5.6281e-01,  3.5659e-01, -3.6096e-01, -9.9662e-02,
#         5.2753e-01,  3.8839e-01,  9.6185e-01,  1.8841e-01,  3.0741e-01,
#        -8.7842e-01, -3.2442e-01,  1.1202e+00,  7.5126e-02,  4.2661e-01,
#        -6.0651e-01, -1.3893e-01,  4.7862e-02, -4.5158e-01,  9.3723e-02,
#         1.7463e-01,  1.0962e+00, -1.0044e+00,  6.3889e-02,  3.8002e-01,
#         2.1109e-01, -6.6247e-01, -4.0736e-01,  8.9442e-01, -6.0974e-01,
#        -1.8577e-01, -1.9913e-01, -6.9226e-01, -3.1806e-01, -7.8565e-01,
#         2.3831e-01,  1.2992e-01,  8.7721e-02,  4.3205e-01, -2.2662e-01,
#         3.1549e-01, -3.1748e-01, -2.4632e-03,  1.6615e-01,  4.2358e-01,
#        -1.8087e+00, -3.6699e-01,  2.3949e-01,  2.5458e+00,  3.6111e-01,
#         3.9486e-02,  4.8607e-01, -3.6974e-01,  5.7282e-02, -4.9317e-01,
#         2.2765e-01,  7.9966e-01,  2.1428e-01,  6.9811e-01,  1.1262e+00,
#        -1.3526e-01,  7.1972e-01, -9.9605e-04, -2.6842e-01, -8.3038e-01,
#         2.1780e-01,  3.4355e-01,  3.7731e-01, -4.0251e-01,  3.3124e-01,
#         1.2576e+00, -2.7196e-01, -8.6093e-01,  9.0053e-02, -2.4876e+00,
#         4.5200e-01,  6.6945e-01, -5.4648e-01, -1.0324e-01, -1.6979e-01,
#         5.9437e-01,  1.1280e+00,  7.5755e-01, -5.9160e-02,  1.5152e-01,
#        -2.8388e-01,  4.9452e-01, -9.1703e-01,  9.1289e-01, -3.0927e-01],
#       dtype=float32)

# %% [markdown]
# > CYC notes:<br>
# > From the above output,<br>
# > This is the word embedding vector (in a 100-dim space) for the word "computer"<br>
# > Each number in the vector reflects how this word relates to other words.<br>
# > Words with similar meanings / used in similar contexts will have similar vectors.<br>
# > Ref: https://medium.com/biased-algorithms/word-embeddings-in-python-a8085488d244

# %% [markdown]
# ### Finding most similar words
#
# Here we define a function to find the most similar words to a given word. The similarity is computed using the cosine similarity between the word embeddings. It can also accept multiple words, and it will take the average of the embeddings of the words to find the most similar words.

# %%
def most_similar(words, topn=10):
    query_emb = 0
    # If we have a list of words instead of one word
    # (bonus question)
    if type(words) == list:
        for word in words:
            query_emb += get_emb(word)
    else:
        query_emb = get_emb(words)

    query_emb = query_emb / np.linalg.norm(query_emb)

    # Large numpy vector with all cosine similarities
    # between emb and all other words
    cosines = np.dot(glove_embeddings_normed, query_emb)

    # topn most similar indexes corresponding to cosines
    idxs = np.argsort(cosines)[::-1][:topn]

    # pretty return with word and similarity
    return [(inv_index[idx], cosines[idx]) for idx in idxs]

# %%
most_similar("cpu")
# Out:
# [('cpu', np.float32(1.0)),
#  ('processor', np.float32(0.77934384)),
#  ('cpus', np.float32(0.76518446)),
#  ('microprocessor', np.float32(0.7360635)),
#  ('processors', np.float32(0.6734816)),
#  ('motherboard', np.float32(0.6675774)),
#  ('x86', np.float32(0.66559225)),
#  ('pentium', np.float32(0.6475851)),
#  ('gpu', np.float32(0.6448883)),
#  ('i/o', np.float32(0.6352353))]

# %% [markdown]
# > CYC notes:<br>
# > From the above, cpu is itself, so the similarity is definitely 1; CPUs are a type of processor, so it has a strong semantic overlap.

# %%
most_similar("nvidia")
# Out:
# [('nvidia', np.float32(0.9999999)),
#  ('geforce', np.float32(0.70250356)),
#  ('gpu', np.float32(0.6787485)),
#  ('ati', np.float32(0.6703709)),
#  ('chipset', np.float32(0.638131)),
#  ('gpus', np.float32(0.6330379)),
#  ('amd', np.float32(0.60988235)),
#  ('chipsets', np.float32(0.6023344)),
#  ('tesla', np.float32(0.585502)),
#  ('intel', np.float32(0.56317127))]

# %%
most_similar("1")
# Out:
# [('1', np.float32(1.0000001)),
#  ('2', np.float32(0.9713605)),
#  ('3', np.float32(0.9551016)),
#  ('4', np.float32(0.93552566)),
#  ('5', np.float32(0.9143884)),
#  ('6', np.float32(0.90160364)),
#  ('8', np.float32(0.8834145)),
#  ('7', np.float32(0.87454295)),
#  ('9', np.float32(0.8470948)),
#  ('10', np.float32(0.81597936))]

# %%
# bonus: sum of two word embeddings
most_similar(["toronto", "leaf"])
# Out:
# [('leaf', np.float32(0.7868253)),
#  ('toronto', np.float32(0.77712166)),
#  ('maple', np.float32(0.7656235)),
#  ('red', np.float32(0.65742534)),
#  ('buffalo', np.float32(0.6446778)),
#  ('leafs', np.float32(0.63587487)),
#  ('montreal', np.float32(0.63387585)),
#  ('boston', np.float32(0.62637895)),
#  ('seattle', np.float32(0.62145466)),
#  ('cleveland', np.float32(0.6207881))]

# %% [markdown]
# ### Displaying vectors with  t-SNE

# %%
from sklearn.manifold import TSNE # helps reduce the dimensionality of word embeddings from 100 dimensions to 2D, leading to possibliy visualize them

word_emb_tsne = TSNE(perplexity=30).fit_transform(glove_embeddings_normed[:1000])
    # fit_transform(): runs the dimensionality reduction and returns the 2D coordinates
    # TSNE(perplexity=30): project these 100D vectors into 2D space for visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 40))
axis = plt.gca()
np.set_printoptions(suppress=True)
plt.scatter(word_emb_tsne[:, 0], word_emb_tsne[:, 1], marker=".", s=1)

for idx in range(1000):
    plt.annotate(inv_index[idx],
                 xy=(word_emb_tsne[idx, 0], word_emb_tsne[idx, 1]),
                 xytext=(0, 0), textcoords='offset points')
plt.savefig("tsne.png")
plt.show()

# %% [markdown]
# ### Using pre-trained embeddings in our model
#
# We want to use these pre-trained embeddings for transfer learning. This process is rather similar than transfer learning in image recognition: the features learnt on words might help us bootstrap the learning process, and increase performance if we don't have enough training data.
#
# - We initialize embedding matrix from the model with Glove embeddings:
#  - take all unique words from our BBC news dataset to build a vocabulary (`MAX_NB_WORDS = 20000`), and look up their Glove embedding
#  - place the Glove embedding at the corresponding index in the matrix
#  - if the word is not in the Glove vocabulary, we only place zeros in the matrix

# %%
EMBEDDING_DIM = 100

# prepare embedding matrix
nb_words_in_matrix = 0
nb_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = get_emb(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector # Place the Glove embedding at the corresponding index in the matrix
        nb_words_in_matrix = nb_words_in_matrix + 1
        
print("added %d words in the embedding matrix" % nb_words_in_matrix)
# Out:
# added 17275 words in the embedding matrix

# %% [markdown]
# Build a layer with pre-trained embeddings:

# %%
pretrained_embedding_layer = Embedding(
    MAX_NB_WORDS, EMBEDDING_DIM,
    weights=[embedding_matrix],
)

# %% [markdown]
# ### A model with pre-trained Embeddings
#
# Now we can build a model with pre-trained embeddings. We will use the same architecture as before, but we will use the `pretrained_embedding_layer` as the first layer of the model.

# %%
model = Sequential([
    # Add the pre-defined and pre-trained embedding layer
    pretrained_embedding_layer,
    GlobalAveragePooling1D(),
    Dense(N_CLASSES, activation='softmax')
])

# Set the embedding layer's trainable attribute to False to not fine-tune the embeddings - you can try to change this
model.layers[0].trainable = False
# this freezes the embedding weightsm meaning they won't be updated during training
# this makes faster training
# trade-off: lose the ability to adapt embeddings to the dataset of interest being used here 

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, validation_split=0.1, epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4138 - loss: 1.5276 - val_accuracy: 0.7734 - val_loss: 1.2283
# Epoch 2/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8276 - loss: 1.1468 - val_accuracy: 0.8818 - val_loss: 0.9638
# Epoch 3/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.9045 - val_accuracy: 0.8670 - val_loss: 0.8034
# Epoch 4/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9046 - loss: 0.7565 - val_accuracy: 0.9212 - val_loss: 0.6780
# Epoch 5/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9177 - loss: 0.6432 - val_accuracy: 0.9409 - val_loss: 0.5887
# Epoch 6/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9155 - loss: 0.5792 - val_accuracy: 0.9310 - val_loss: 0.5260
# Epoch 7/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9344 - loss: 0.5142 - val_accuracy: 0.9360 - val_loss: 0.4751
# Epoch 8/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.4655 - val_accuracy: 0.9212 - val_loss: 0.4496
# Epoch 9/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9303 - loss: 0.4284 - val_accuracy: 0.9261 - val_loss: 0.4088
# Epoch 10/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.4125 - val_accuracy: 0.9261 - val_loss: 0.3796
# Epoch 11/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9341 - loss: 0.3865 - val_accuracy: 0.9261 - val_loss: 0.3613
# Epoch 12/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9384 - loss: 0.3564 - val_accuracy: 0.9360 - val_loss: 0.3391
# Epoch 13/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9466 - loss: 0.3270 - val_accuracy: 0.9458 - val_loss: 0.3263
# Epoch 14/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9419 - loss: 0.3101 - val_accuracy: 0.9360 - val_loss: 0.3178
# Epoch 15/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9517 - loss: 0.2944 - val_accuracy: 0.9360 - val_loss: 0.2999

# %% [markdown]
# ### Reality check
#
# On small/medium datasets (few 10,000s) of reasonably large documents (e.g. more than a few paragraphs), simpler classification methods usually perform better, and are much more efficient to train and use. Here are two resources to go further, if you are curious:
# - Naive Bayes approach, using scikit-learn [http://scikit-learn.org/stable/datasets/twenty_newsgroups.html](http://scikit-learn.org/stable/datasets/twenty_newsgroups.html)
# - Alec Radford (OpenAI) gave a very interesting presentation, showing that you need a VERY large dataset to have real gains from GRU/LSTM in text classification [https://www.slideshare.net/odsc/alec-radfordodsc-presentation](https://www.slideshare.net/odsc/alec-radfordodsc-presentation)
#
# Training deep architectures from random init on text classification is usually a waste of time.
#
# However, when looking at features, one can see that classification using simple methods isn't very robust, and won't generalize well to slightly different domains (e.g. forum posts => emails)
#
# Nowadays, the strategy would be to use pre-trained deep network (BERT) to extract features and fit a linear classifer on top of this. This is especially useful when classifying short texts (e.g. one or a few sentences) as this kind of tasks can be very sensitive to understanding the meaning resulting from intra-sentence interactions between words. The next session on attentional mechanisms and pre-trained transformer-based word models will explain this in more details.
